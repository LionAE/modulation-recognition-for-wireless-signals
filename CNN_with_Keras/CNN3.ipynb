# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Amiralae/modulation-recognition-for-wireless-signals/blob/master/CNN_with_Keras/CNN3.ipynb)

# %%
# importing the necessary packages
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import sys
sys.path.append('../modulation')
import numpy as np
import cPickle, keras, h5py
import keras.models as models
import keras.optimizers
import matplotlib.pyplot as plt
from keras.layers.core import Reshape, Dropout, Flatten, Dense, Activation
from keras.layers.convolutional import Convolution2D, ZeroPadding2D

name = "CNN"

# load the RadioMl.10A data
Xd = cPickle.load(open("RML2016.10a_dict (4).dat", 'rb'))
snrs, mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1, 0])
X = []
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod, snr)])
        for i in range(Xd[(mod, snr)].shape[0]):
            lbl.append((mod, snr))
X = np.vstack(X)

# Split the data into train, Validation and test data
# initialize randomly the seed
np.random.seed(1567)
n_example = X.shape[0]
# we choose 80 % of input data for training
n_train = n_example * 0.8
# we randomly choose the input training signals
train_idx = np.random.choice(range(0, n_example), size=int(n_train), replace=False)
# the rest will be used fo test
test_idx = list(set(range(0, n_example)) - set(train_idx))
X_train = X[train_idx]
X_test = X[test_idx]


# Function for Hot Encoding the vectors
def to_onehot(vec):
    vec_hot = np.zeros([len(vec), max(vec) + 1])
    vec_hot[np.arange(len(vec)), vec] = 1
    return vec_hot


Y_train = to_onehot(map(lambda x: mods.index(lbl[x][0]), train_idx))
Y_test = to_onehot(map(lambda x: mods.index(lbl[x][0]), test_idx))
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
# types of modulation
classes = mods
# For the architecture of CNN, it consists of 4 conv layer
# first conv layer of 256 filters of size 1*3
# second conv layer of 256 filters of size 2*3
# third and fourth conv layer of 80 filters of size 1*3
# first dense layer of 128 units
# second one for output containing number of output classes
# building the model
dr = 0.5   # dropout rate 50 %
model = models.Sequential()
model.add(Reshape([1]+in_shp, input_shape=in_shp))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(256, (1, 5), border_mode='valid', activation="relu", name="conv1", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(256, (1, 3), border_mode='valid', activation="relu", name="conv2", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(128, (1, 3), border_mode='valid', activation="relu", name="conv3", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(80, (1, 3), border_mode='valid', activation="relu", name="conv4", init='glorot_uniform'))
model.add(Flatten())
model.add(Dense(256, activation='relu', init='he_normal', name="dense1"))
model.add(Dense(len(classes), init='he_normal', name="dense2"))
model.add(Activation('softmax'))
model.add(Reshape([len(classes)]))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Set up some params
nb_epoch = 150     # number of epochs to train on
batch_size = 1024  # training batch size
# perform training ...
#   - call the main training loop in keras for our network+dataset
filepath = "convmodrecnets_%s_0.5.wts.h5" % (name)
history = model.fit(X_train,
    Y_train,
    batch_size=batch_size,
    nb_epoch=nb_epoch,
    verbose=2,
    validation_data=(X_test, Y_test))
# Show loss curves
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()
plt.savefig('%s Training performance' %('CNN'))
score = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
print('evaluate_score:', score)
# Out:
# ((176000, 2, 128), [2, 128])
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_7 (Reshape)          (None, 1, 2, 128)         0
# _________________________________________________________________
# zero_padding2d_21 (ZeroPaddi (None, 1, 6, 128)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 1, 2, 256)         164096
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 1, 2, 256)         0
# _________________________________________________________________
# zero_padding2d_22 (ZeroPaddi (None, 1, 6, 256)         0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 1, 4, 256)         196864
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 1, 4, 256)         0
# _________________________________________________________________
# zero_padding2d_23 (ZeroPaddi (None, 1, 8, 256)         0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 1, 6, 128)         98432
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 1, 6, 128)         0
# _________________________________________________________________
# zero_padding2d_24 (ZeroPaddi (None, 1, 10, 128)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 1, 8, 80)          30800
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense1 (Dense)               (None, 256)               164096
# _________________________________________________________________
# dense2 (Dense)               (None, 11)                2827
# _________________________________________________________________
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:65: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 5), kernel_initializer="glorot_uniform", name="conv1", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:68: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 3), kernel_initializer="glorot_uniform", name="conv2", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:71: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 3), kernel_initializer="glorot_uniform", name="conv3", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:74: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(80, (1, 3), kernel_initializer="glorot_uniform", name="conv4", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:76: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, kernel_initializer="he_normal", activation="relu", name="dense1")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:77: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(11, kernel_initializer="he_normal", name="dense2")`
# activation_17 (Activation)   (None, 11)                0
# _________________________________________________________________
# reshape_8 (Reshape)          (None, 11)                0
# =================================================================
# Total params: 657,115
# Trainable params: 657,115
# Non-trainable params: 0
# _________________________________________________________________
# Train on 176000 samples, validate on 44000 samples
# Epoch 1/150
#  - 7s - loss: 2.1246 - acc: 0.1964 - val_loss: 1.8511 - val_acc: 0.2992
# Epoch 2/150
#  - 6s - loss: 1.8018 - acc: 0.3134 - val_loss: 1.6713 - val_acc: 0.3646
# Epoch 3/150
#  - 6s - loss: 1.6818 - acc: 0.3518 - val_loss: 1.6093 - val_acc: 0.3860
# Epoch 4/150
#  - 6s - loss: 1.6409 - acc: 0.3674 - val_loss: 1.5828 - val_acc: 0.3961
# Epoch 5/150
#  - 6s - loss: 1.6156 - acc: 0.3758 - val_loss: 1.5614 - val_acc: 0.3984
# Epoch 6/150
#  - 6s - loss: 1.6005 - acc: 0.3820 - val_loss: 1.5551 - val_acc: 0.4024
# Epoch 7/150
#  - 6s - loss: 1.5841 - acc: 0.3886 - val_loss: 1.5445 - val_acc: 0.4089
# Epoch 8/150
#  - 6s - loss: 1.5752 - acc: 0.3929 - val_loss: 1.5355 - val_acc: 0.4172
# Epoch 9/150
#  - 6s - loss: 1.5653 - acc: 0.3961 - val_loss: 1.5384 - val_acc: 0.4172
# Epoch 10/150
#  - 6s - loss: 1.5583 - acc: 0.3979 - val_loss: 1.5286 - val_acc: 0.4139
# Epoch 11/150
#  - 6s - loss: 1.5515 - acc: 0.4003 - val_loss: 1.5284 - val_acc: 0.4196
# Epoch 12/150
#  - 6s - loss: 1.5433 - acc: 0.4028 - val_loss: 1.5314 - val_acc: 0.4171
# Epoch 13/150
#  - 6s - loss: 1.5382 - acc: 0.4056 - val_loss: 1.5318 - val_acc: 0.4162
# Epoch 14/150
#  - 6s - loss: 1.5303 - acc: 0.4083 - val_loss: 1.5300 - val_acc: 0.4200
# Epoch 15/150
# Epoch 70/150
#  - 6s - loss: 1.3439 - acc: 0.4679 - val_loss: 1.5130 - val_acc: 0.4137
# Epoch 71/150
#  - 6s - loss: 1.3464 - acc: 0.4677 - val_loss: 1.5024 - val_acc: 0.4174
# Epoch 72/150
#  - 6s - loss: 1.3420 - acc: 0.4669 - val_loss: 1.5108 - val_acc: 0.4093
# Epoch 73/150
#  - 6s - loss: 1.3440 - acc: 0.4676 - val_loss: 1.5229 - val_acc: 0.4047
# Epoch 74/150
#  - 6s - loss: 1.3409 - acc: 0.4692 - val_loss: 1.5311 - val_acc: 0.4018
# Epoch 75/150
#  - 6s - loss: 1.3377 - acc: 0.4702 - val_loss: 1.5151 - val_acc: 0.4060
# Epoch 76/150
#  - 6s - loss: 1.3378 - acc: 0.4703 - val_loss: 1.5173 - val_acc: 0.4123
# Epoch 77/150
#  - 6s - loss: 1.3360 - acc: 0.4715 - val_loss: 1.5327 - val_acc: 0.4015
# Epoch 78/150
#  - 6s - loss: 1.3341 - acc: 0.4702 - val_loss: 1.5402 - val_acc: 0.4079
# Epoch 79/150
#  - 6s - loss: 1.3305 - acc: 0.4729 - val_loss: 1.5168 - val_acc: 0.4110
# Epoch 80/150
#  - 6s - loss: 1.3341 - acc: 0.4723 - val_loss: 1.5184 - val_acc: 0.4116
# Epoch 81/150
#  - 6s - loss: 1.3323 - acc: 0.4720 - val_loss: 1.5348 - val_acc: 0.3987
# Epoch 82/150
#  - 6s - loss: 1.3286 - acc: 0.4729 - val_loss: 1.5171 - val_acc: 0.4073
# Epoch 83/150
#  - 6s - loss: 1.3277 - acc: 0.4751 - val_loss: 1.5267 - val_acc: 0.4024
# Epoch 84/150
#  - 6s - loss: 1.3251 - acc: 0.4753 - val_loss: 1.5422 - val_acc: 0.4033
# Epoch 85/150
#  - 6s - loss: 1.3278 - acc: 0.4733 - val_loss: 1.5403 - val_acc: 0.3972
# Epoch 86/150
#  - 6s - loss: 1.3242 - acc: 0.4747 - val_loss: 1.5428 - val_acc: 0.4037
# Epoch 87/150
#  - 6s - loss: 1.3227 - acc: 0.4762 - val_loss: 1.5214 - val_acc: 0.4121
# Epoch 88/150
#  - 6s - loss: 1.3224 - acc: 0.4748 - val_loss: 1.5266 - val_acc: 0.4046
# Epoch 89/150
#  - 6s - loss: 1.3207 - acc: 0.4759 - val_loss: 1.5541 - val_acc: 0.3930
# Epoch 90/150
#  - 6s - loss: 1.3202 - acc: 0.4765 - val_loss: 1.5573 - val_acc: 0.4007
# Epoch 91/150
#  - 6s - loss: 1.3191 - acc: 0.4778 - val_loss: 1.5582 - val_acc: 0.4019
# Epoch 92/150
#  - 6s - loss: 1.3178 - acc: 0.4787 - val_loss: 1.5626 - val_acc: 0.3960
# Epoch 93/150
#  - 6s - loss: 1.3154 - acc: 0.4779 - val_loss: 1.5426 - val_acc: 0.4049
# Epoch 94/150
#  - 6s - loss: 1.3153 - acc: 0.4784 - val_loss: 1.5492 - val_acc: 0.4027
# Epoch 95/150
#  - 6s - loss: 1.3168 - acc: 0.4791 - val_loss: 1.5544 - val_acc: 0.4035
# Epoch 96/150
#  - 6s - loss: 1.3126 - acc: 0.4804 - val_loss: 1.5851 - val_acc: 0.3857
# Epoch 97/150
#  - 6s - loss: 1.3101 - acc: 0.4802 - val_loss: 1.5562 - val_acc: 0.4039
# Epoch 98/150
#  - 6s - loss: 1.3114 - acc: 0.4807 - val_loss: 1.6009 - val_acc: 0.3910
# Epoch 99/150
#  - 6s - loss: 1.3116 - acc: 0.4791 - val_loss: 1.5687 - val_acc: 0.3947
# Epoch 100/150
#  - 6s - loss: 1.3067 - acc: 0.4825 - val_loss: 1.5745 - val_acc: 0.4004
# Epoch 101/150
#  - 6s - loss: 1.3073 - acc: 0.4813 - val_loss: 1.5611 - val_acc: 0.3962
# Epoch 102/150
#  - 6s - loss: 1.3073 - acc: 0.4818 - val_loss: 1.5615 - val_acc: 0.3962
# Epoch 103/150
#  - 6s - loss: 1.3067 - acc: 0.4814 - val_loss: 1.5730 - val_acc: 0.3978
# Epoch 104/150
#  - 6s - loss: 1.3047 - acc: 0.4836 - val_loss: 1.5753 - val_acc: 0.3967
# Epoch 105/150
#  - 6s - loss: 1.3046 - acc: 0.4829 - val_loss: 1.5599 - val_acc: 0.3969
# Epoch 106/150
#  - 6s - loss: 1.3027 - acc: 0.4827 - val_loss: 1.5613 - val_acc: 0.3973
# Epoch 107/150
#  - 6s - loss: 1.3015 - acc: 0.4837 - val_loss: 1.6028 - val_acc: 0.3958
# Epoch 108/150
#  - 6s - loss: 1.3003 - acc: 0.4853 - val_loss: 1.5776 - val_acc: 0.3942
# Epoch 109/150
#  - 6s - loss: 1.3003 - acc: 0.4861 - val_loss: 1.5780 - val_acc: 0.3935
# Epoch 110/150
#  - 6s - loss: 1.2981 - acc: 0.4852 - val_loss: 1.5865 - val_acc: 0.3960
# Epoch 111/150
#  - 6s - loss: 1.2991 - acc: 0.4862 - val_loss: 1.5883 - val_acc: 0.3961
# Epoch 112/150
#  - 6s - loss: 1.2959 - acc: 0.4854 - val_loss: 1.5957 - val_acc: 0.3880
# Epoch 113/150
#  - 6s - loss: 1.2952 - acc: 0.4860 - val_loss: 1.5899 - val_acc: 0.3915
# Epoch 114/150
#  - 6s - loss: 1.2939 - acc: 0.4863 - val_loss: 1.5918 - val_acc: 0.3921
# Epoch 115/150
#  - 6s - loss: 1.2908 - acc: 0.4888 - val_loss: 1.6210 - val_acc: 0.3886
# Epoch 116/150
#  - 6s - loss: 1.2941 - acc: 0.4864 - val_loss: 1.5911 - val_acc: 0.3975
# Epoch 117/150
#  - 6s - loss: 1.2926 - acc: 0.4884 - val_loss: 1.5794 - val_acc: 0.3939
# Epoch 118/150
#  - 6s - loss: 1.2903 - acc: 0.4884 - val_loss: 1.5787 - val_acc: 0.3934
# Epoch 119/150
#  - 6s - loss: 1.2916 - acc: 0.4878 - val_loss: 1.5915 - val_acc: 0.3936
# Epoch 120/150
#  - 6s - loss: 1.2902 - acc: 0.4900 - val_loss: 1.6076 - val_acc: 0.3880
# Epoch 121/150
#  - 6s - loss: 1.2882 - acc: 0.4895 - val_loss: 1.6036 - val_acc: 0.3859
# Epoch 122/150
#  - 6s - loss: 1.2876 - acc: 0.4907 - val_loss: 1.6226 - val_acc: 0.3821
# Epoch 123/150
#  - 6s - loss: 1.2884 - acc: 0.4892 - val_loss: 1.6332 - val_acc: 0.3813
# Epoch 124/150
#  - 6s - loss: 1.2859 - acc: 0.4920 - val_loss: 1.6184 - val_acc: 0.3892
# Epoch 125/150
#  - 6s - loss: 1.2873 - acc: 0.4892 - val_loss: 1.6013 - val_acc: 0.3886
# Epoch 126/150
#  - 6s - loss: 1.2841 - acc: 0.4914 - val_loss: 1.6461 - val_acc: 0.3848
# Epoch 127/150
#  - 6s - loss: 1.2854 - acc: 0.4915 - val_loss: 1.5983 - val_acc: 0.3923
# Epoch 128/150
#  - 6s - loss: 1.2815 - acc: 0.4925 - val_loss: 1.6157 - val_acc: 0.3912
# Epoch 129/150
#  - 6s - loss: 1.2827 - acc: 0.4934 - val_loss: 1.6055 - val_acc: 0.3918
# Epoch 130/150
#  - 6s - loss: 1.2806 - acc: 0.4921 - val_loss: 1.6358 - val_acc: 0.3874
# Epoch 131/150
#  - 6s - loss: 1.2837 - acc: 0.4915 - val_loss: 1.6106 - val_acc: 0.3862
# Epoch 132/150
#  - 6s - loss: 1.2775 - acc: 0.4943 - val_loss: 1.6291 - val_acc: 0.3890
# Epoch 133/150
#  - 6s - loss: 1.2786 - acc: 0.4938 - val_loss: 1.6362 - val_acc: 0.3855
# Epoch 134/150
#  - 6s - loss: 1.2799 - acc: 0.4940 - val_loss: 1.6105 - val_acc: 0.3860
# Epoch 135/150
#  - 6s - loss: 1.2776 - acc: 0.4927 - val_loss: 1.6332 - val_acc: 0.3900
# Epoch 136/150
#  - 6s - loss: 1.2782 - acc: 0.4943 - val_loss: 1.6430 - val_acc: 0.3872
# Epoch 137/150
#  - 6s - loss: 1.2744 - acc: 0.4943 - val_loss: 1.6699 - val_acc: 0.3762
# Epoch 138/150
#  - 6s - loss: 1.2769 - acc: 0.4950 - val_loss: 1.6546 - val_acc: 0.3858
# Epoch 139/150
#  - 6s - loss: 1.2738 - acc: 0.4938 - val_loss: 1.6424 - val_acc: 0.3812
# Epoch 140/150
#  - 6s - loss: 1.2731 - acc: 0.4940 - val_loss: 1.6365 - val_acc: 0.3879
# Epoch 141/150
#  - 6s - loss: 1.2755 - acc: 0.4944 - val_loss: 1.6302 - val_acc: 0.3887
# Epoch 142/150
#  - 6s - loss: 1.2723 - acc: 0.4962 - val_loss: 1.6031 - val_acc: 0.3927
# Epoch 143/150
#  - 6s - loss: 1.2722 - acc: 0.4958 - val_loss: 1.6597 - val_acc: 0.3889
# Epoch 144/150
#  - 6s - loss: 1.2700 - acc: 0.4950 - val_loss: 1.6823 - val_acc: 0.3790
# Epoch 145/150
#  - 6s - loss: 1.2696 - acc: 0.4973 - val_loss: 1.6315 - val_acc: 0.3898
# Epoch 146/150
#  - 6s - loss: 1.2680 - acc: 0.4968 - val_loss: 1.6627 - val_acc: 0.3858
# Epoch 147/150
#  - 6s - loss: 1.2694 - acc: 0.4967 - val_loss: 1.6114 - val_acc: 0.3899
# Epoch 148/150
#  - 6s - loss: 1.2686 - acc: 0.4966 - val_loss: 1.6570 - val_acc: 0.3818
# Epoch 149/150
#  - 6s - loss: 1.2689 - acc: 0.4974 - val_loss: 1.6783 - val_acc: 0.3831
# Epoch 150/150
#  - 6s - loss: 1.2642 - acc: 0.4973 - val_loss: 1.6737 - val_acc: 0.3771
# ('evaluate_score:', [1.6736929929039694, 0.37713636377724735])
