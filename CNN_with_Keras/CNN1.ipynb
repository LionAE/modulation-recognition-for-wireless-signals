# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Amiralae/modulation-recognition-for-wireless-signals/blob/master/CNN_with_Keras/CNN1.ipynb)

# %%
# importing the necessary packages
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import sys
sys.path.append('../modulation')
import numpy as np
import cPickle, keras, h5py
import keras.models as models
import keras.optimizers
import matplotlib.pyplot as plt
from keras.layers.core import Reshape, Dropout, Flatten, Dense, Activation
from keras.layers.convolutional import Convolution2D, ZeroPadding2D

name = "CNN"

# load the RadioMl.10A data
Xd = cPickle.load(open("RML2016.10a_dict (4).dat", 'rb'))
snrs, mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1, 0])
X = []
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod, snr)])
        for i in range(Xd[(mod, snr)].shape[0]):
            lbl.append((mod, snr))
X = np.vstack(X)

# Split the data into train, Validation and test data
# initialize randomly the seed
np.random.seed(1567)
n_example = X.shape[0]
# we choose 70 % of input data for training
n_train = n_example * 0.8
# we randomly choose the input training signals
train_idx = np.random.choice(range(0, n_example), size=int(n_train), replace=False)
# the rest will be used fo test
test_idx = list(set(range(0, n_example)) - set(train_idx))
X_train = X[train_idx]
X_test = X[test_idx]


# Function for Hot Encoding the vectors
def to_onehot(vec):
    vec_hot = np.zeros([len(vec), max(vec) + 1])
    vec_hot[np.arange(len(vec)), vec] = 1
    return vec_hot


Y_train = to_onehot(map(lambda x: mods.index(lbl[x][0]), train_idx))
Y_test = to_onehot(map(lambda x: mods.index(lbl[x][0]), test_idx))
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
# types of modulation
classes = mods
# For the architecture of CNN, it consists of 4 conv layer
# first conv layer of 256 filters of size 1*3
# second conv layer of 256 filters of size 2*3
# third and fourth conv layer of 80 filters of size 1*3
# first dense layer of 128 units
# second one for output containing number of output classes
# building the model
dr = 0.5   # dropout rate 50 %
model = models.Sequential()
model.add(Reshape([1]+in_shp, input_shape=in_shp))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(256, (1, 5), border_mode='valid', activation="relu", name="conv1", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(256, (1, 5), border_mode='valid', activation="relu", name="conv2", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(80, (1, 3), border_mode='valid', activation="relu", name="conv3", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(ZeroPadding2D((0, 2)))
model.add(Convolution2D(80, (1, 3), border_mode='valid', activation="relu", name="conv4", init='glorot_uniform'))
model.add(Dropout(dr))
model.add(Flatten())
model.add(Dense(256, activation='relu', init='he_normal', name="dense1"))
model.add(Dropout(dr))
model.add(Dense(len(classes), init='he_normal', name="dense2"))
model.add(Activation('softmax'))
model.add(Reshape([len(classes)]))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Set up some params
nb_epoch = 150     # number of epochs to train on
batch_size = 1024  # training batch size
# perform training ...
#   - call the main training loop in keras for our network+dataset
filepath = "convmodrecnets_%s_0.5.wts.h5" % (name)
history = model.fit(X_train,
    Y_train,
    batch_size=batch_size,
    nb_epoch=nb_epoch,
    verbose=2,
    validation_data=(X_test, Y_test))
# Show loss curves
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()
plt.savefig('%s Training performance' %('CNN'))

# we re-load the best weights once training is finished
model.load_weights(filepath)
score = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
print('evaluate_score:', score)
# Out:
# ((176000, 2, 128), [2, 128])
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:65: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 5), kernel_initializer="glorot_uniform", name="conv1", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:68: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 5), kernel_initializer="glorot_uniform", name="conv2", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:71: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(80, (1, 3), kernel_initializer="glorot_uniform", name="conv3", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:74: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(80, (1, 3), kernel_initializer="glorot_uniform", name="conv4", activation="relu", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:77: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, kernel_initializer="he_normal", activation="relu", name="dense1")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:79: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(11, kernel_initializer="he_normal", name="dense2")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 1, 2, 128)         0
# _________________________________________________________________
# zero_padding2d_13 (ZeroPaddi (None, 1, 6, 128)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 1, 2, 256)         164096
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 2, 256)         0
# _________________________________________________________________
# zero_padding2d_14 (ZeroPaddi (None, 1, 6, 256)         0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 1, 2, 256)         327936
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 2, 256)         0
# _________________________________________________________________
# zero_padding2d_15 (ZeroPaddi (None, 1, 6, 256)         0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 1, 4, 80)          61520
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1, 4, 80)          0
# _________________________________________________________________
# zero_padding2d_16 (ZeroPaddi (None, 1, 8, 80)          0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 1, 6, 80)          19280
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1, 6, 80)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense1 (Dense)               (None, 256)               123136
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 11)                2827
# _________________________________________________________________
# activation_15 (Activation)   (None, 11)                0
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 11)                0
# =================================================================
# Total params: 698,795
# Trainable params: 698,795
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python2.7/dist-packages/keras/models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 176000 samples, validate on 44000 samples
# Epoch 1/150
#  - 7s - loss: 2.2014 - acc: 0.1580 - val_loss: 1.9080 - val_acc: 0.2763
# Epoch 2/150
#  - 5s - loss: 1.8822 - acc: 0.2762 - val_loss: 1.7959 - val_acc: 0.3085
# Epoch 3/150
#  - 5s - loss: 1.8084 - acc: 0.3104 - val_loss: 1.7272 - val_acc: 0.3526
# Epoch 4/150
#  - 5s - loss: 1.7469 - acc: 0.3347 - val_loss: 1.6828 - val_acc: 0.3640
# Epoch 5/150
#  - 5s - loss: 1.7111 - acc: 0.3470 - val_loss: 1.6517 - val_acc: 0.3725
# Epoch 6/150
#  - 5s - loss: 1.6799 - acc: 0.3554 - val_loss: 1.6043 - val_acc: 0.3828
# Epoch 7/150
#  - 5s - loss: 1.6522 - acc: 0.3680 - val_loss: 1.5968 - val_acc: 0.3853
# Epoch 8/150
#  - 5s - loss: 1.6331 - acc: 0.3729 - val_loss: 1.5808 - val_acc: 0.3844
# Epoch 9/150
#  - 5s - loss: 1.6162 - acc: 0.3774 - val_loss: 1.5586 - val_acc: 0.3957
# Epoch 10/150
#  - 5s - loss: 1.5986 - acc: 0.3824 - val_loss: 1.5371 - val_acc: 0.4038
# Epoch 11/150
#  - 5s - loss: 1.5791 - acc: 0.3862 - val_loss: 1.5041 - val_acc: 0.4153
# Epoch 12/150
#  - 5s - loss: 1.5557 - acc: 0.3927 - val_loss: 1.4946 - val_acc: 0.4171
# Epoch 13/150
#  - 5s - loss: 1.5434 - acc: 0.3975 - val_loss: 1.4915 - val_acc: 0.4136
# Epoch 14/150
#  - 5s - loss: 1.5322 - acc: 0.4008 - val_loss: 1.4815 - val_acc: 0.4160
# Epoch 15/150
#  - 5s - loss: 1.5258 - acc: 0.4019 - val_loss: 1.4791 - val_acc: 0.4247
# Epoch 16/150
#  - 5s - loss: 1.5177 - acc: 0.4049 - val_loss: 1.4735 - val_acc: 0.4218
# Epoch 17/150
#  - 5s - loss: 1.5121 - acc: 0.4062 - val_loss: 1.4701 - val_acc: 0.4228
# Epoch 18/150
#  - 5s - loss: 1.5068 - acc: 0.4082 - val_loss: 1.4706 - val_acc: 0.4172
# Epoch 19/150
#  - 5s - loss: 1.5036 - acc: 0.4101 - val_loss: 1.4600 - val_acc: 0.4241
# Epoch 20/150
#  - 5s - loss: 1.4969 - acc: 0.4123 - val_loss: 1.4638 - val_acc: 0.4242
# Epoch 21/150
#  - 5s - loss: 1.4934 - acc: 0.4118 - val_loss: 1.4609 - val_acc: 0.4235
# Epoch 22/150
#  - 5s - loss: 1.4911 - acc: 0.4134 - val_loss: 1.4694 - val_acc: 0.4265
# Epoch 23/150
#  - 5s - loss: 1.4862 - acc: 0.4160 - val_loss: 1.4559 - val_acc: 0.4283
# Epoch 24/150
#  - 5s - loss: 1.4810 - acc: 0.4176 - val_loss: 1.4586 - val_acc: 0.4289
# Epoch 25/150
#  - 5s - loss: 1.4801 - acc: 0.4183 - val_loss: 1.4569 - val_acc: 0.4282
# Epoch 26/150
#  - 5s - loss: 1.4759 - acc: 0.4198 - val_loss: 1.4550 - val_acc: 0.4240
# Epoch 27/150
#  - 5s - loss: 1.4740 - acc: 0.4205 - val_loss: 1.4504 - val_acc: 0.4339
# Epoch 28/150
#  - 5s - loss: 1.4726 - acc: 0.4217 - val_loss: 1.4544 - val_acc: 0.4337
# Epoch 29/150
#  - 5s - loss: 1.4694 - acc: 0.4208 - val_loss: 1.4563 - val_acc: 0.4329
# Epoch 30/150
#  - 5s - loss: 1.4647 - acc: 0.4227 - val_loss: 1.4500 - val_acc: 0.4403
# Epoch 31/150
#  - 5s - loss: 1.4641 - acc: 0.4230 - val_loss: 1.4543 - val_acc: 0.4388
# Epoch 32/150
#  - 5s - loss: 1.4625 - acc: 0.4239 - val_loss: 1.4629 - val_acc: 0.4341
# Epoch 33/150
#  - 5s - loss: 1.4620 - acc: 0.4248 - val_loss: 1.4517 - val_acc: 0.4410
# Epoch 34/150
#  - 5s - loss: 1.4584 - acc: 0.4251 - val_loss: 1.4502 - val_acc: 0.4369
# Epoch 35/150
#  - 5s - loss: 1.4554 - acc: 0.4256 - val_loss: 1.4585 - val_acc: 0.4358
# Epoch 36/150
#  - 5s - loss: 1.4547 - acc: 0.4255 - val_loss: 1.4571 - val_acc: 0.4369
# Epoch 37/150
#  - 5s - loss: 1.4519 - acc: 0.4281 - val_loss: 1.4424 - val_acc: 0.4374
# Epoch 38/150
#  - 5s - loss: 1.4510 - acc: 0.4291 - val_loss: 1.4560 - val_acc: 0.4397
# Epoch 39/150
#  - 5s - loss: 1.4497 - acc: 0.4293 - val_loss: 1.4512 - val_acc: 0.4405
# Epoch 40/150
#  - 5s - loss: 1.4449 - acc: 0.4300 - val_loss: 1.4429 - val_acc: 0.4423
# Epoch 41/150
#  - 5s - loss: 1.4442 - acc: 0.4293 - val_loss: 1.4494 - val_acc: 0.4439
# Epoch 42/150
#  - 5s - loss: 1.4462 - acc: 0.4304 - val_loss: 1.4480 - val_acc: 0.4449
# Epoch 43/150
#  - 5s - loss: 1.4432 - acc: 0.4309 - val_loss: 1.4520 - val_acc: 0.4439
# Epoch 44/150
#  - 5s - loss: 1.4399 - acc: 0.4327 - val_loss: 1.4539 - val_acc: 0.4431
# Epoch 45/150
#  - 5s - loss: 1.4411 - acc: 0.4308 - val_loss: 1.4506 - val_acc: 0.4409
# Epoch 46/150
#  - 5s - loss: 1.4386 - acc: 0.4323 - val_loss: 1.4504 - val_acc: 0.4394
# Epoch 47/150
#  - 5s - loss: 1.4355 - acc: 0.4345 - val_loss: 1.4461 - val_acc: 0.4473
# Epoch 48/150
#  - 5s - loss: 1.4351 - acc: 0.4332 - val_loss: 1.4490 - val_acc: 0.4389
# Epoch 49/150
#  - 5s - loss: 1.4361 - acc: 0.4329 - val_loss: 1.4472 - val_acc: 0.4409
# Epoch 50/150
#  - 5s - loss: 1.4330 - acc: 0.4351 - val_loss: 1.4508 - val_acc: 0.4448
# Epoch 51/150
#  - 5s - loss: 1.4307 - acc: 0.4361 - val_loss: 1.4479 - val_acc: 0.4451
# Epoch 52/150
#  - 5s - loss: 1.4307 - acc: 0.4355 - val_loss: 1.4533 - val_acc: 0.4473
# Epoch 53/150
#  - 5s - loss: 1.4272 - acc: 0.4360 - val_loss: 1.4533 - val_acc: 0.4440
# Epoch 54/150
#  - 5s - loss: 1.4272 - acc: 0.4368 - val_loss: 1.4510 - val_acc: 0.4434
# Epoch 55/150
#  - 5s - loss: 1.4251 - acc: 0.4383 - val_loss: 1.4457 - val_acc: 0.4494
# Epoch 56/150
#  - 5s - loss: 1.4261 - acc: 0.4357 - val_loss: 1.4509 - val_acc: 0.4454
# Epoch 57/150
#  - 5s - loss: 1.4247 - acc: 0.4369 - val_loss: 1.4553 - val_acc: 0.4395
# Epoch 58/150
#  - 5s - loss: 1.4206 - acc: 0.4392 - val_loss: 1.4507 - val_acc: 0.4415
# Epoch 59/150
#  - 5s - loss: 1.4228 - acc: 0.4385 - val_loss: 1.4460 - val_acc: 0.4514
# Epoch 60/150
#  - 5s - loss: 1.4172 - acc: 0.4399 - val_loss: 1.4484 - val_acc: 0.4482
# Epoch 61/150
#  - 5s - loss: 1.4198 - acc: 0.4395 - val_loss: 1.4523 - val_acc: 0.4400
# Epoch 62/150
#  - 5s - loss: 1.4164 - acc: 0.4412 - val_loss: 1.4450 - val_acc: 0.4526
# Epoch 63/150
#  - 5s - loss: 1.4162 - acc: 0.4396 - val_loss: 1.4495 - val_acc: 0.4435
# Epoch 64/150
#  - 5s - loss: 1.4139 - acc: 0.4408 - val_loss: 1.4532 - val_acc: 0.4484
# Epoch 65/150
#  - 5s - loss: 1.4141 - acc: 0.4406 - val_loss: 1.4541 - val_acc: 0.4471
# Epoch 66/150
#  - 5s - loss: 1.4123 - acc: 0.4404 - val_loss: 1.4555 - val_acc: 0.4433
# Epoch 67/150
#  - 5s - loss: 1.4106 - acc: 0.4432 - val_loss: 1.4518 - val_acc: 0.4403
# Epoch 68/150
#  - 5s - loss: 1.4099 - acc: 0.4420 - val_loss: 1.4525 - val_acc: 0.4480
# Epoch 69/150
#  - 5s - loss: 1.4089 - acc: 0.4432 - val_loss: 1.4638 - val_acc: 0.4353
# Epoch 70/150
#  - 5s - loss: 1.4066 - acc: 0.4439 - val_loss: 1.4523 - val_acc: 0.4468
# Epoch 71/150
#  - 5s - loss: 1.4053 - acc: 0.4445 - val_loss: 1.4605 - val_acc: 0.4398
# Epoch 72/150
#  - 5s - loss: 1.4057 - acc: 0.4439 - val_loss: 1.4515 - val_acc: 0.4462
# Epoch 73/150
#  - 5s - loss: 1.4046 - acc: 0.4446 - val_loss: 1.4463 - val_acc: 0.4514
# Epoch 74/150
#  - 5s - loss: 1.4028 - acc: 0.4450 - val_loss: 1.4598 - val_acc: 0.4374
# Epoch 75/150
#  - 5s - loss: 1.4036 - acc: 0.4449 - val_loss: 1.4538 - val_acc: 0.4488
# Epoch 76/150
#  - 5s - loss: 1.3991 - acc: 0.4461 - val_loss: 1.4596 - val_acc: 0.4438
# Epoch 77/150
#  - 5s - loss: 1.4015 - acc: 0.4455 - val_loss: 1.4610 - val_acc: 0.4406
# Epoch 78/150
#  - 5s - loss: 1.4010 - acc: 0.4447 - val_loss: 1.4533 - val_acc: 0.4456
# Epoch 79/150
#  - 5s - loss: 1.3993 - acc: 0.4472 - val_loss: 1.4599 - val_acc: 0.4418
# Epoch 80/150
#  - 5s - loss: 1.3977 - acc: 0.4466 - val_loss: 1.4582 - val_acc: 0.4418
# Epoch 81/150
#  - 5s - loss: 1.3975 - acc: 0.4456 - val_loss: 1.4619 - val_acc: 0.4417
# Epoch 82/150
#  - 5s - loss: 1.3935 - acc: 0.4479 - val_loss: 1.4694 - val_acc: 0.4364
# Epoch 83/150
#  - 5s - loss: 1.3960 - acc: 0.4480 - val_loss: 1.4716 - val_acc: 0.4387
# Epoch 84/150
#  - 5s - loss: 1.3947 - acc: 0.4488 - val_loss: 1.4539 - val_acc: 0.4473
# Epoch 85/150
#  - 5s - loss: 1.3929 - acc: 0.4493 - val_loss: 1.4586 - val_acc: 0.4462
# Epoch 86/150
#  - 5s - loss: 1.3913 - acc: 0.4497 - val_loss: 1.4575 - val_acc: 0.4409
# Epoch 87/150
#  - 5s - loss: 1.3904 - acc: 0.4502 - val_loss: 1.4734 - val_acc: 0.4333
# Epoch 88/150
#  - 5s - loss: 1.3895 - acc: 0.4497 - val_loss: 1.4558 - val_acc: 0.4464
# Epoch 89/150
#  - 5s - loss: 1.3906 - acc: 0.4499 - val_loss: 1.4649 - val_acc: 0.4407
# Epoch 90/150
#  - 5s - loss: 1.3885 - acc: 0.4505 - val_loss: 1.4654 - val_acc: 0.4355
# Epoch 91/150
#  - 5s - loss: 1.3903 - acc: 0.4502 - val_loss: 1.4703 - val_acc: 0.4401
# Epoch 92/150
#  - 5s - loss: 1.3869 - acc: 0.4506 - val_loss: 1.4644 - val_acc: 0.4441
# Epoch 93/150
#  - 5s - loss: 1.3850 - acc: 0.4505 - val_loss: 1.4591 - val_acc: 0.4459
# Epoch 94/150
#  - 5s - loss: 1.3860 - acc: 0.4516 - val_loss: 1.4603 - val_acc: 0.4388
# Epoch 95/150
#  - 5s - loss: 1.3850 - acc: 0.4527 - val_loss: 1.4589 - val_acc: 0.4390
# Epoch 96/150
#  - 5s - loss: 1.3848 - acc: 0.4531 - val_loss: 1.4605 - val_acc: 0.4382
# Epoch 97/150
#  - 5s - loss: 1.3826 - acc: 0.4507 - val_loss: 1.4649 - val_acc: 0.4412
# Epoch 98/150
#  - 5s - loss: 1.3800 - acc: 0.4525 - val_loss: 1.4680 - val_acc: 0.4395
# Epoch 99/150
#  - 5s - loss: 1.3809 - acc: 0.4533 - val_loss: 1.4623 - val_acc: 0.4396
# Epoch 100/150
#  - 5s - loss: 1.3808 - acc: 0.4542 - val_loss: 1.4615 - val_acc: 0.4384
# Epoch 101/150
#  - 5s - loss: 1.3794 - acc: 0.4535 - val_loss: 1.4651 - val_acc: 0.4379
# Epoch 102/150
#  - 5s - loss: 1.3751 - acc: 0.4552 - val_loss: 1.4687 - val_acc: 0.4348
# Epoch 103/150
#  - 5s - loss: 1.3760 - acc: 0.4548 - val_loss: 1.4617 - val_acc: 0.4384
# Epoch 104/150
#  - 5s - loss: 1.3762 - acc: 0.4561 - val_loss: 1.4721 - val_acc: 0.4317
# Epoch 105/150
#  - 5s - loss: 1.3781 - acc: 0.4556 - val_loss: 1.4737 - val_acc: 0.4375
# Epoch 106/150
#  - 5s - loss: 1.3732 - acc: 0.4558 - val_loss: 1.4723 - val_acc: 0.4360
# Epoch 107/150
#  - 5s - loss: 1.3749 - acc: 0.4558 - val_loss: 1.4696 - val_acc: 0.4426
# Epoch 108/150
#  - 5s - loss: 1.3750 - acc: 0.4563 - val_loss: 1.4710 - val_acc: 0.4318
# Epoch 109/150
#  - 5s - loss: 1.3713 - acc: 0.4574 - val_loss: 1.4690 - val_acc: 0.4368
# Epoch 110/150
#  - 5s - loss: 1.3734 - acc: 0.4570 - val_loss: 1.4652 - val_acc: 0.4401
# Epoch 111/150
#  - 5s - loss: 1.3687 - acc: 0.4588 - val_loss: 1.4896 - val_acc: 0.4359
# Epoch 112/150
#  - 5s - loss: 1.3697 - acc: 0.4577 - val_loss: 1.4645 - val_acc: 0.4387
# Epoch 113/150
#  - 5s - loss: 1.3711 - acc: 0.4576 - val_loss: 1.4738 - val_acc: 0.4398
# Epoch 114/150
#  - 5s - loss: 1.3686 - acc: 0.4575 - val_loss: 1.4696 - val_acc: 0.4376
# Epoch 115/150
#  - 5s - loss: 1.3697 - acc: 0.4580 - val_loss: 1.4558 - val_acc: 0.4398
# Epoch 116/150
#  - 5s - loss: 1.3689 - acc: 0.4581 - val_loss: 1.4702 - val_acc: 0.4382
# Epoch 117/150
#  - 5s - loss: 1.3658 - acc: 0.4601 - val_loss: 1.4836 - val_acc: 0.4347
# Epoch 118/150
#  - 5s - loss: 1.3678 - acc: 0.4586 - val_loss: 1.4803 - val_acc: 0.4342
# Epoch 119/150
#  - 5s - loss: 1.3668 - acc: 0.4577 - val_loss: 1.4734 - val_acc: 0.4311
# Epoch 120/150
#  - 5s - loss: 1.3637 - acc: 0.4600 - val_loss: 1.4747 - val_acc: 0.4348
# Epoch 121/150
#  - 5s - loss: 1.3634 - acc: 0.4609 - val_loss: 1.4694 - val_acc: 0.4372
# Epoch 122/150
#  - 5s - loss: 1.3659 - acc: 0.4601 - val_loss: 1.4854 - val_acc: 0.4265
# Epoch 123/150
#  - 5s - loss: 1.3646 - acc: 0.4588 - val_loss: 1.4760 - val_acc: 0.4291
# Epoch 124/150
#  - 5s - loss: 1.3618 - acc: 0.4606 - val_loss: 1.4698 - val_acc: 0.4345
# Epoch 125/150
#  - 5s - loss: 1.3624 - acc: 0.4616 - val_loss: 1.4655 - val_acc: 0.4376
# Epoch 126/150
#  - 5s - loss: 1.3607 - acc: 0.4609 - val_loss: 1.4835 - val_acc: 0.4323
# Epoch 127/150
#  - 5s - loss: 1.3566 - acc: 0.4635 - val_loss: 1.4791 - val_acc: 0.4327
# Epoch 128/150
#  - 5s - loss: 1.3600 - acc: 0.4624 - val_loss: 1.4854 - val_acc: 0.4352
# Epoch 129/150
#  - 5s - loss: 1.3553 - acc: 0.4628 - val_loss: 1.4771 - val_acc: 0.4310
# Epoch 130/150
#  - 5s - loss: 1.3585 - acc: 0.4618 - val_loss: 1.4842 - val_acc: 0.4314
# Epoch 131/150
#  - 5s - loss: 1.3583 - acc: 0.4619 - val_loss: 1.4770 - val_acc: 0.4348
# Epoch 132/150
#  - 5s - loss: 1.3542 - acc: 0.4637 - val_loss: 1.4803 - val_acc: 0.4342
# Epoch 133/150
#  - 5s - loss: 1.3533 - acc: 0.4644 - val_loss: 1.4728 - val_acc: 0.4410
# Epoch 134/150
#  - 5s - loss: 1.3525 - acc: 0.4649 - val_loss: 1.4889 - val_acc: 0.4259
# Epoch 135/150
#  - 5s - loss: 1.3565 - acc: 0.4638 - val_loss: 1.4930 - val_acc: 0.4294
# Epoch 136/150
#  - 5s - loss: 1.3531 - acc: 0.4649 - val_loss: 1.4752 - val_acc: 0.4376
# Epoch 137/150
#  - 5s - loss: 1.3523 - acc: 0.4647 - val_loss: 1.4828 - val_acc: 0.4270
# Epoch 138/150
#  - 5s - loss: 1.3544 - acc: 0.4637 - val_loss: 1.4860 - val_acc: 0.4282
# Epoch 139/150
#  - 5s - loss: 1.3530 - acc: 0.4654 - val_loss: 1.4864 - val_acc: 0.4318
# Epoch 140/150
#  - 5s - loss: 1.3507 - acc: 0.4652 - val_loss: 1.4785 - val_acc: 0.4350
# Epoch 141/150
#  - 5s - loss: 1.3523 - acc: 0.4637 - val_loss: 1.4958 - val_acc: 0.4270
# Epoch 142/150
#  - 5s - loss: 1.3485 - acc: 0.4661 - val_loss: 1.4851 - val_acc: 0.4307
# Epoch 143/150
#  - 5s - loss: 1.3481 - acc: 0.4664 - val_loss: 1.4817 - val_acc: 0.4310
# Epoch 144/150
#  - 5s - loss: 1.3499 - acc: 0.4655 - val_loss: 1.4897 - val_acc: 0.4267
# Epoch 145/150
#  - 5s - loss: 1.3483 - acc: 0.4662 - val_loss: 1.4944 - val_acc: 0.4289
# Epoch 146/150
#  - 5s - loss: 1.3476 - acc: 0.4675 - val_loss: 1.4815 - val_acc: 0.4315
# Epoch 147/150
#  - 5s - loss: 1.3458 - acc: 0.4680 - val_loss: 1.4889 - val_acc: 0.4278
# Epoch 148/150
#  - 5s - loss: 1.3451 - acc: 0.4675 - val_loss: 1.5011 - val_acc: 0.4244
# Epoch 149/150
#  - 5s - loss: 1.3448 - acc: 0.4675 - val_loss: 1.4897 - val_acc: 0.4297
# Epoch 150/150
#  - 5s - loss: 1.3436 - acc: 0.4692 - val_loss: 1.4707 - val_acc: 0.4355
# IOErrorTraceback (most recent call last)
# <ipython-input-7-277a68bd7bd4> in <module>()
#     104
#     105 # we re-load the best weights once training is finished
# --> 106 model.load_weights(filepath)
#     107 score = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
#     108 print('evaluate_score:', score)
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#     722         if h5py is None:
#     723             raise ImportError('`load_weights` requires h5py.')
# --> 724         with h5py.File(filepath, mode='r') as f:
#     725             if 'layer_names' not in f.attrs and 'model_weights' in f:
#     726                 f = f['model_weights']
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# IOError: Unable to open file (unable to open file: name = 'convmodrecnets_CNN_0.5.wts.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
