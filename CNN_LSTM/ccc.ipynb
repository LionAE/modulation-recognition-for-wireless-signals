# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Amiralae/modulation-recognition-for-wireless-signals/blob/master/CNN_LSTM/ccc.ipynb)

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import sys
sys.path.append('../modulation')
import numpy as np
import matplotlib.pyplot as plt
import keras, cPickle
from keras.layers import LSTM, Input
from keras.models import Model
from keras.layers.core import Reshape, Dropout, Dense, Activation
from keras.layers.convolutional import Conv2D, ZeroPadding2D
from sklearn.metrics import confusion_matrix
from sklearn.metrics import cohen_kappa_score, accuracy_score

name = 'CNN_LSTM'

Xd = cPickle.load(open("RML2016.10a_dict (4).dat", 'rb'))
snrs, mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1, 0])
X = []
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod, snr)])
        for i in range(Xd[(mod, snr)].shape[0]):
            lbl.append((mod, snr))

X = np.vstack(X)
np.random.seed(1567)
n_example = X.shape[0]
n_train = n_example * 0.7
train_idx = np.random.choice(range(0,n_example), size=int(n_train), replace=False)
test_idx = list(set(range(0, n_example)) - set(train_idx))
X_train = X[train_idx]
X_test = X[test_idx]

def to_onehot(vec):
    vec_hot = np.zeros([len(vec), max(vec) + 1])
    vec_hot[np.arange(len(vec)), vec] = 1
    return vec_hot


Y_train = to_onehot(map(lambda x: mods.index(lbl[x][0]), train_idx))
Y_test = to_onehot(map(lambda x: mods.index(lbl[x][0]), test_idx))
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
classes = mods

dr = 0.5  # dropout rate l

# Reshape [N,2,128] to [N,1,2,128] on input
input_x = Input(shape=(1, 2, 128))

# channels_first corresponds to inputs with shape (batch, channels, height, width).
# Build our MOdel
input_x_padding = ZeroPadding2D((0, 2), data_format="channels_first")(input_x)

layer1 = Conv2D(50, (1, 7), padding='valid', activation="relu", name="conv1", init='glorot_uniform', data_format="channels_first")(input_x_padding)
layer1 = Dropout(dr)(layer1)
layer1_padding = ZeroPadding2D((0, 2), data_format="channels_first")(layer1)

layer2 = Conv2D(50, (1, 7), padding="valid", activation="relu", name="conv2", init='glorot_uniform', data_format="channels_first")(layer1_padding)
layer2 = Dropout(dr)(layer2)
layer2 = ZeroPadding2D((0, 2), data_format="channels_first")(layer2)

layer3 = Conv2D(50, (1, 7), padding='valid', activation="relu", name="conv3", init='glorot_uniform', data_format="channels_first")(layer2)
layer3 = Dropout(dr)(layer3)

concat = keras.layers.concatenate([layer1, layer3])
concat_size = list(np.shape(concat))
input_dim = int(concat_size[-1] * concat_size[-2])
timesteps = int(concat_size[-3])
concat = Reshape((timesteps, input_dim))(concat)
lstm_out = LSTM(50, input_dim=input_dim, input_length=timesteps)(concat)
layer_dense1 = Dense(256, activation='relu', init='he_normal', name="dense1")(lstm_out)
layer_dropout = Dropout(dr)(layer_dense1)
layer_dense2 = Dense(len(classes), init='he_normal', name="dense2")(layer_dropout)
layer_softmax = Activation('softmax')(layer_dense2)

output = Reshape([len(classes)])(layer_softmax)

model = Model(inputs=input_x, outputs=output)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# End of building, we will start fitting the neural network
# Set up some params
epochs = 150  # number of epochs to train on
batch_size = 1024  # training batch size default1024
filepath = "convmodrecnets_%s_0.5.wts.h5" % ('CNN_LSTM')

X_train = np.reshape(X_train, (-1, 1, 2, 128))
X_test = np.reshape(X_test, (-1, 1, 2, 128))

history = model.fit(X_train,
                    Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=2,
                    validation_data=(X_test, Y_test))
# Show loss curves
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()
plt.savefig('%s Training performance' %(name))
# plt.show()

score = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
print('evaluate_score:', score)
# Out:
# ((154000, 2, 128), [2, 128])
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:57: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(50, (1, 7), kernel_initializer="glorot_uniform", name="conv1", activation="relu", data_format="channels_first", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:61: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(50, (1, 7), kernel_initializer="glorot_uniform", name="conv2", activation="relu", data_format="channels_first", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:65: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(50, (1, 7), kernel_initializer="glorot_uniform", name="conv3", activation="relu", data_format="channels_first", padding="valid")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:73: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:73: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(50, input_shape=(50, 496))`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:74: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, kernel_initializer="he_normal", activation="relu", name="dense1")`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:76: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(11, kernel_initializer="he_normal", name="dense2")`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 1, 2, 128)    0
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 1, 2, 132)    0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 50, 2, 126)   400         zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 50, 2, 126)   0           conv1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 50, 2, 130)   0           dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 50, 2, 124)   17550       zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 50, 2, 124)   0           conv2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 50, 2, 128)   0           dropout_35[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 50, 2, 122)   17550       zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 50, 2, 122)   0           conv3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 50, 2, 248)   0           dropout_34[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 50, 496)      0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 50)           109400      reshape_11[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256)          13056       lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 256)          0           dense1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 11)           2827        dropout_37[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 11)           0           dense2[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 11)           0           activation_19[0][0]
# ==================================================================================================
# Total params: 160,783
# Trainable params: 160,783
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 154000 samples, validate on 66000 samples
# Epoch 1/150
#  - 44s - loss: 2.2620 - acc: 0.1412 - val_loss: 2.1512 - val_acc: 0.1907
# Epoch 2/150
#  - 43s - loss: 2.0549 - acc: 0.2291 - val_loss: 1.9166 - val_acc: 0.2804
# Epoch 3/150
#  - 43s - loss: 1.8823 - acc: 0.2919 - val_loss: 1.7839 - val_acc: 0.3327
# Epoch 4/150
#  - 43s - loss: 1.7720 - acc: 0.3346 - val_loss: 1.7410 - val_acc: 0.3556
# Epoch 5/150
#  - 43s - loss: 1.6495 - acc: 0.3795 - val_loss: 1.6212 - val_acc: 0.3926
# Epoch 6/150
#  - 43s - loss: 1.5423 - acc: 0.4194 - val_loss: 1.5453 - val_acc: 0.4188
# Epoch 7/150
#  - 43s - loss: 1.4914 - acc: 0.4379 - val_loss: 1.5314 - val_acc: 0.4299
# Epoch 8/150
#  - 43s - loss: 1.4505 - acc: 0.4539 - val_loss: 1.5172 - val_acc: 0.4388
# Epoch 9/150
#  - 43s - loss: 1.4258 - acc: 0.4624 - val_loss: 1.3943 - val_acc: 0.4802
# Epoch 10/150
#  - 43s - loss: 1.4180 - acc: 0.4655 - val_loss: 1.4067 - val_acc: 0.4750
# Epoch 11/150
#  - 43s - loss: 1.3963 - acc: 0.4746 - val_loss: 1.4438 - val_acc: 0.4639
# Epoch 12/150
#  - 43s - loss: 1.3868 - acc: 0.4790 - val_loss: 1.3326 - val_acc: 0.5007
# Epoch 13/150
#  - 43s - loss: 1.3838 - acc: 0.4802 - val_loss: 1.3744 - val_acc: 0.4862
# Epoch 14/150
#  - 43s - loss: 1.3711 - acc: 0.4846 - val_loss: 1.3938 - val_acc: 0.4732
# Epoch 15/150
#  - 43s - loss: 1.3670 - acc: 0.4878 - val_loss: 1.4380 - val_acc: 0.4659
# Epoch 16/150
#  - 43s - loss: 1.3586 - acc: 0.4903 - val_loss: 1.3224 - val_acc: 0.5024
# Epoch 17/150
#  - 43s - loss: 1.3583 - acc: 0.4889 - val_loss: 1.3481 - val_acc: 0.4933
# Epoch 18/150
#  - 43s - loss: 1.3517 - acc: 0.4938 - val_loss: 1.3161 - val_acc: 0.5043
# Epoch 19/150
#  - 43s - loss: 1.3471 - acc: 0.4942 - val_loss: 1.3027 - val_acc: 0.5074
# Epoch 20/150
#  - 43s - loss: 1.3415 - acc: 0.4952 - val_loss: 1.3355 - val_acc: 0.5012
# Epoch 21/150
#  - 43s - loss: 1.3419 - acc: 0.4963 - val_loss: 1.3173 - val_acc: 0.5048
# Epoch 22/150
#  - 43s - loss: 1.3376 - acc: 0.4971 - val_loss: 1.3557 - val_acc: 0.4928
# Epoch 23/150
#  - 43s - loss: 1.3352 - acc: 0.4994 - val_loss: 1.3478 - val_acc: 0.4905
# Epoch 24/150
#  - 43s - loss: 1.3322 - acc: 0.4983 - val_loss: 1.3671 - val_acc: 0.4871
# Epoch 25/150
#  - 43s - loss: 1.3333 - acc: 0.4984 - val_loss: 1.3151 - val_acc: 0.5066
# Epoch 26/150
#  - 43s - loss: 1.3326 - acc: 0.5000 - val_loss: 1.3009 - val_acc: 0.5108
# Epoch 27/150
#  - 43s - loss: 1.3240 - acc: 0.5023 - val_loss: 1.3561 - val_acc: 0.4942
# Epoch 28/150
#  - 43s - loss: 1.3225 - acc: 0.5037 - val_loss: 1.3181 - val_acc: 0.5018
# Epoch 29/150
#  - 43s - loss: 1.3220 - acc: 0.5022 - val_loss: 1.3231 - val_acc: 0.5045
# Epoch 30/150
#  - 43s - loss: 1.3171 - acc: 0.5061 - val_loss: 1.3701 - val_acc: 0.4867
# Epoch 31/150
#  - 43s - loss: 1.3145 - acc: 0.5063 - val_loss: 1.3213 - val_acc: 0.5012
# Epoch 32/150
#  - 43s - loss: 1.3190 - acc: 0.5042 - val_loss: 1.3103 - val_acc: 0.5074
# Epoch 33/150
#  - 43s - loss: 1.3135 - acc: 0.5060 - val_loss: 1.3207 - val_acc: 0.5007
# Epoch 34/150
#  - 43s - loss: 1.3050 - acc: 0.5089 - val_loss: 1.3195 - val_acc: 0.5033
# Epoch 35/150
#  - 43s - loss: 1.3076 - acc: 0.5086 - val_loss: 1.2627 - val_acc: 0.5219
# Epoch 36/150
#  - 43s - loss: 1.3046 - acc: 0.5100 - val_loss: 1.2856 - val_acc: 0.5161
# Epoch 37/150
#  - 43s - loss: 1.3071 - acc: 0.5092 - val_loss: 1.2892 - val_acc: 0.5131
# Epoch 38/150
#  - 43s - loss: 1.3014 - acc: 0.5109 - val_loss: 1.3033 - val_acc: 0.5087
# Epoch 39/150
#  - 43s - loss: 1.2979 - acc: 0.5126 - val_loss: 1.2937 - val_acc: 0.5098
# Epoch 40/150
#  - 43s - loss: 1.2974 - acc: 0.5121 - val_loss: 1.3258 - val_acc: 0.5027
# Epoch 41/150
#  - 43s - loss: 1.3028 - acc: 0.5103 - val_loss: 1.2840 - val_acc: 0.5158
# Epoch 42/150
#  - 43s - loss: 1.2950 - acc: 0.5134 - val_loss: 1.2687 - val_acc: 0.5216
# Epoch 43/150
#  - 43s - loss: 1.2925 - acc: 0.5141 - val_loss: 1.2837 - val_acc: 0.5163
# Epoch 44/150
#  - 42s - loss: 1.2897 - acc: 0.5143 - val_loss: 1.3130 - val_acc: 0.5065
# Epoch 45/150
#  - 42s - loss: 1.2867 - acc: 0.5149 - val_loss: 1.2858 - val_acc: 0.5161
# Epoch 46/150
#  - 42s - loss: 1.2907 - acc: 0.5143 - val_loss: 1.2899 - val_acc: 0.5145
# Epoch 47/150
#  - 42s - loss: 1.2893 - acc: 0.5147 - val_loss: 1.3035 - val_acc: 0.5097
# Epoch 48/150
#  - 42s - loss: 1.2836 - acc: 0.5165 - val_loss: 1.2978 - val_acc: 0.5105
# Epoch 49/150
#  - 42s - loss: 1.2815 - acc: 0.5169 - val_loss: 1.2938 - val_acc: 0.5120
# Epoch 50/150
#  - 42s - loss: 1.2840 - acc: 0.5176 - val_loss: 1.2860 - val_acc: 0.5147
# Epoch 51/150
#  - 42s - loss: 1.2826 - acc: 0.5158 - val_loss: 1.2780 - val_acc: 0.5160
# Epoch 52/150
#  - 42s - loss: 1.2781 - acc: 0.5188 - val_loss: 1.2637 - val_acc: 0.5231
# Epoch 53/150
#  - 42s - loss: 1.2738 - acc: 0.5198 - val_loss: 1.2779 - val_acc: 0.5172
# Epoch 54/150
#  - 42s - loss: 1.2772 - acc: 0.5183 - val_loss: 1.2967 - val_acc: 0.5106
# Epoch 55/150
#  - 42s - loss: 1.2750 - acc: 0.5194 - val_loss: 1.2543 - val_acc: 0.5242
# Epoch 56/150
#  - 42s - loss: 1.2753 - acc: 0.5193 - val_loss: 1.2514 - val_acc: 0.5270
# Epoch 57/150
#  - 42s - loss: 1.2700 - acc: 0.5206 - val_loss: 1.2708 - val_acc: 0.5214
# Epoch 58/150
#  - 42s - loss: 1.2685 - acc: 0.5214 - val_loss: 1.2642 - val_acc: 0.5228
# Epoch 59/150
#  - 42s - loss: 1.2637 - acc: 0.5227 - val_loss: 1.2524 - val_acc: 0.5262
# Epoch 60/150
#  - 42s - loss: 1.2662 - acc: 0.5223 - val_loss: 1.2470 - val_acc: 0.5306
# Epoch 61/150
#  - 42s - loss: 1.2630 - acc: 0.5230 - val_loss: 1.2411 - val_acc: 0.5308
# Epoch 62/150
#  - 42s - loss: 1.2623 - acc: 0.5236 - val_loss: 1.2705 - val_acc: 0.5199
# Epoch 63/150
#  - 42s - loss: 1.2568 - acc: 0.5262 - val_loss: 1.2385 - val_acc: 0.5316
# Epoch 64/150
#  - 42s - loss: 1.2555 - acc: 0.5254 - val_loss: 1.2675 - val_acc: 0.5193
# Epoch 65/150
#  - 42s - loss: 1.2515 - acc: 0.5278 - val_loss: 1.2657 - val_acc: 0.5206
# Epoch 66/150
#  - 42s - loss: 1.2500 - acc: 0.5273 - val_loss: 1.2406 - val_acc: 0.5310
# Epoch 67/150
#  - 42s - loss: 1.2484 - acc: 0.5282 - val_loss: 1.3215 - val_acc: 0.5031
# Epoch 68/150
#  - 42s - loss: 1.2565 - acc: 0.5251 - val_loss: 1.2774 - val_acc: 0.5178
# Epoch 69/150
#  - 42s - loss: 1.2455 - acc: 0.5300 - val_loss: 1.2595 - val_acc: 0.5217
# Epoch 70/150
#  - 42s - loss: 1.2443 - acc: 0.5299 - val_loss: 1.2592 - val_acc: 0.5249
# Epoch 71/150
#  - 42s - loss: 1.2410 - acc: 0.5314 - val_loss: 1.2507 - val_acc: 0.5272
# Epoch 72/150
#  - 42s - loss: 1.2429 - acc: 0.5298 - val_loss: 1.2355 - val_acc: 0.5332
# Epoch 73/150
#  - 42s - loss: 1.2381 - acc: 0.5319 - val_loss: 1.2478 - val_acc: 0.5292
# Epoch 74/150
#  - 42s - loss: 1.2343 - acc: 0.5333 - val_loss: 1.2238 - val_acc: 0.5397
# Epoch 75/150
#  - 42s - loss: 1.2344 - acc: 0.5329 - val_loss: 1.2306 - val_acc: 0.5343
# Epoch 76/150
#  - 42s - loss: 1.2332 - acc: 0.5328 - val_loss: 1.2449 - val_acc: 0.5303
# Epoch 77/150
#  - 42s - loss: 1.2290 - acc: 0.5347 - val_loss: 1.2607 - val_acc: 0.5239
# Epoch 78/150
#  - 42s - loss: 1.2275 - acc: 0.5363 - val_loss: 1.2237 - val_acc: 0.5376
# Epoch 79/150
#  - 42s - loss: 1.2268 - acc: 0.5356 - val_loss: 1.2356 - val_acc: 0.5355
# Epoch 80/150
#  - 42s - loss: 1.2245 - acc: 0.5369 - val_loss: 1.2277 - val_acc: 0.5357
# Epoch 81/150
#  - 42s - loss: 1.2186 - acc: 0.5389 - val_loss: 1.2484 - val_acc: 0.5307
# Epoch 82/150
#  - 42s - loss: 1.2212 - acc: 0.5380 - val_loss: 1.2045 - val_acc: 0.5434
# Epoch 83/150
#  - 42s - loss: 1.2162 - acc: 0.5395 - val_loss: 1.2134 - val_acc: 0.5424
# Epoch 84/150
#  - 42s - loss: 1.2196 - acc: 0.5392 - val_loss: 1.2352 - val_acc: 0.5336
# Epoch 85/150
#  - 42s - loss: 1.2146 - acc: 0.5403 - val_loss: 1.2161 - val_acc: 0.5404
# Epoch 86/150
#  - 42s - loss: 1.2107 - acc: 0.5415 - val_loss: 1.2112 - val_acc: 0.5426
# Epoch 87/150
#  - 42s - loss: 1.2106 - acc: 0.5415 - val_loss: 1.2387 - val_acc: 0.5340
# Epoch 88/150
#  - 42s - loss: 1.2133 - acc: 0.5415 - val_loss: 1.2195 - val_acc: 0.5386
# Epoch 89/150
#  - 42s - loss: 1.2088 - acc: 0.5423 - val_loss: 1.2071 - val_acc: 0.5467
# Epoch 90/150
#  - 42s - loss: 1.2043 - acc: 0.5446 - val_loss: 1.1933 - val_acc: 0.5478
# Epoch 91/150
#  - 42s - loss: 1.2048 - acc: 0.5438 - val_loss: 1.2254 - val_acc: 0.5361
# Epoch 92/150
#  - 42s - loss: 1.2009 - acc: 0.5456 - val_loss: 1.2754 - val_acc: 0.5264
# Epoch 93/150
#  - 42s - loss: 1.2018 - acc: 0.5453 - val_loss: 1.2173 - val_acc: 0.5435
# Epoch 94/150
#  - 42s - loss: 1.2011 - acc: 0.5448 - val_loss: 1.2116 - val_acc: 0.5425
# Epoch 95/150
#  - 42s - loss: 1.1993 - acc: 0.5460 - val_loss: 1.2096 - val_acc: 0.5461
# Epoch 96/150
#  - 42s - loss: 1.1959 - acc: 0.5462 - val_loss: 1.2190 - val_acc: 0.5428
# Epoch 97/150
#  - 42s - loss: 1.1975 - acc: 0.5467 - val_loss: 1.2138 - val_acc: 0.5433
# Epoch 98/150
#  - 42s - loss: 1.1961 - acc: 0.5475 - val_loss: 1.2138 - val_acc: 0.5434
# Epoch 99/150
#  - 42s - loss: 1.1899 - acc: 0.5498 - val_loss: 1.2441 - val_acc: 0.5361
# Epoch 100/150
#  - 42s - loss: 1.1941 - acc: 0.5481 - val_loss: 1.1983 - val_acc: 0.5489
# Epoch 101/150
#  - 42s - loss: 1.1907 - acc: 0.5493 - val_loss: 1.2285 - val_acc: 0.5368
# Epoch 102/150
#  - 42s - loss: 1.1889 - acc: 0.5498 - val_loss: 1.2156 - val_acc: 0.5449
# Epoch 103/150
#  - 42s - loss: 1.1879 - acc: 0.5510 - val_loss: 1.1909 - val_acc: 0.5534
# Epoch 104/150
#  - 42s - loss: 1.1851 - acc: 0.5509 - val_loss: 1.1940 - val_acc: 0.5482
# Epoch 105/150
#  - 42s - loss: 1.1842 - acc: 0.5526 - val_loss: 1.2018 - val_acc: 0.5490
# Epoch 106/150
#  - 42s - loss: 1.1834 - acc: 0.5522 - val_loss: 1.1776 - val_acc: 0.5550
# Epoch 107/150
#  - 42s - loss: 1.1801 - acc: 0.5536 - val_loss: 1.2151 - val_acc: 0.5450
# Epoch 108/150
#  - 42s - loss: 1.1834 - acc: 0.5521 - val_loss: 1.1808 - val_acc: 0.5543
# Epoch 109/150
#  - 42s - loss: 1.1830 - acc: 0.5521 - val_loss: 1.1838 - val_acc: 0.5530
# Epoch 110/150
#  - 42s - loss: 1.1808 - acc: 0.5528 - val_loss: 1.1918 - val_acc: 0.5521
# Epoch 111/150
#  - 42s - loss: 1.1802 - acc: 0.5536 - val_loss: 1.1826 - val_acc: 0.5554
# Epoch 112/150
#  - 42s - loss: 1.1789 - acc: 0.5535 - val_loss: 1.1937 - val_acc: 0.5513
# Epoch 113/150
#  - 42s - loss: 1.1787 - acc: 0.5543 - val_loss: 1.2032 - val_acc: 0.5493
# Epoch 114/150
#  - 42s - loss: 1.1785 - acc: 0.5527 - val_loss: 1.1947 - val_acc: 0.5487
# Epoch 115/150
#  - 42s - loss: 1.1754 - acc: 0.5552 - val_loss: 1.1812 - val_acc: 0.5559
# Epoch 116/150
#  - 42s - loss: 1.1750 - acc: 0.5554 - val_loss: 1.1967 - val_acc: 0.5489
# Epoch 117/150
#  - 42s - loss: 1.1739 - acc: 0.5558 - val_loss: 1.1931 - val_acc: 0.5519
# Epoch 118/150
#  - 42s - loss: 1.1751 - acc: 0.5552 - val_loss: 1.1737 - val_acc: 0.5589
# Epoch 119/150
#  - 42s - loss: 1.1725 - acc: 0.5562 - val_loss: 1.2054 - val_acc: 0.5486
# Epoch 120/150
#  - 42s - loss: 1.1726 - acc: 0.5566 - val_loss: 1.2089 - val_acc: 0.5463
# Epoch 121/150
#  - 42s - loss: 1.1724 - acc: 0.5563 - val_loss: 1.1932 - val_acc: 0.5528
# Epoch 122/150
#  - 42s - loss: 1.1715 - acc: 0.5565 - val_loss: 1.1881 - val_acc: 0.5530
# Epoch 123/150
#  - 42s - loss: 1.1695 - acc: 0.5569 - val_loss: 1.2051 - val_acc: 0.5501
# Epoch 124/150
#  - 42s - loss: 1.1681 - acc: 0.5579 - val_loss: 1.1863 - val_acc: 0.5543
# Epoch 125/150
#  - 42s - loss: 1.1659 - acc: 0.5581 - val_loss: 1.1893 - val_acc: 0.5545
# Epoch 126/150
#  - 42s - loss: 1.1667 - acc: 0.5581 - val_loss: 1.1926 - val_acc: 0.5507
# Epoch 127/150
#  - 42s - loss: 1.1658 - acc: 0.5583 - val_loss: 1.2012 - val_acc: 0.5528
# Epoch 128/150
#  - 42s - loss: 1.1651 - acc: 0.5591 - val_loss: 1.2180 - val_acc: 0.5456
# Epoch 129/150
#  - 42s - loss: 1.1648 - acc: 0.5591 - val_loss: 1.1885 - val_acc: 0.5552
# Epoch 130/150
#  - 42s - loss: 1.1647 - acc: 0.5586 - val_loss: 1.1817 - val_acc: 0.5566
# Epoch 131/150
#  - 42s - loss: 1.1641 - acc: 0.5602 - val_loss: 1.1677 - val_acc: 0.5603
# Epoch 132/150
#  - 42s - loss: 1.1642 - acc: 0.5594 - val_loss: 1.1801 - val_acc: 0.5573
# Epoch 133/150
#  - 42s - loss: 1.1633 - acc: 0.5606 - val_loss: 1.1949 - val_acc: 0.5520
# Epoch 134/150
#  - 42s - loss: 1.1613 - acc: 0.5597 - val_loss: 1.2105 - val_acc: 0.5475
# Epoch 135/150
#  - 42s - loss: 1.1633 - acc: 0.5604 - val_loss: 1.1915 - val_acc: 0.5560
# Epoch 136/150
#  - 42s - loss: 1.1607 - acc: 0.5612 - val_loss: 1.1848 - val_acc: 0.5548
# Epoch 137/150
#  - 42s - loss: 1.1586 - acc: 0.5627 - val_loss: 1.1820 - val_acc: 0.5543
# Epoch 138/150
#  - 42s - loss: 1.1609 - acc: 0.5616 - val_loss: 1.1947 - val_acc: 0.5510
# Epoch 139/150
#  - 42s - loss: 1.1585 - acc: 0.5627 - val_loss: 1.1953 - val_acc: 0.5553
# Epoch 140/150
#  - 42s - loss: 1.1588 - acc: 0.5617 - val_loss: 1.1904 - val_acc: 0.5551
# Epoch 141/150
#  - 42s - loss: 1.1562 - acc: 0.5631 - val_loss: 1.1923 - val_acc: 0.5537
# Epoch 142/150
#  - 42s - loss: 1.1573 - acc: 0.5626 - val_loss: 1.1774 - val_acc: 0.5563
# Epoch 143/150
#  - 42s - loss: 1.1558 - acc: 0.5632 - val_loss: 1.1987 - val_acc: 0.5542
# Epoch 144/150
#  - 42s - loss: 1.1561 - acc: 0.5630 - val_loss: 1.1696 - val_acc: 0.5591
# Epoch 145/150
#  - 42s - loss: 1.1553 - acc: 0.5632 - val_loss: 1.1859 - val_acc: 0.5573
# Epoch 146/150
#  - 42s - loss: 1.1571 - acc: 0.5636 - val_loss: 1.1924 - val_acc: 0.5486
# Epoch 147/150
#  - 42s - loss: 1.1552 - acc: 0.5635 - val_loss: 1.1718 - val_acc: 0.5613
# Epoch 148/150
#  - 42s - loss: 1.1539 - acc: 0.5638 - val_loss: 1.1707 - val_acc: 0.5591
# Epoch 149/150
#  - 42s - loss: 1.1543 - acc: 0.5637 - val_loss: 1.1909 - val_acc: 0.5548
# Epoch 150/150
#  - 42s - loss: 1.1532 - acc: 0.5642 - val_loss: 1.1720 - val_acc: 0.5624
# ('evaluate_score:', [1.1720166669686636, 0.5624242423375447])
